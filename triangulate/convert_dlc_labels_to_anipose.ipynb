# %%
from data_conversion import batch_convert_superanimal_to_anipose

# %% [markdown]
# # Convert and copy DLC outputs to Anipose

# %% [markdown]
# ## 1. Organize SuperAnimal outputs by Trial, Box

# %% [markdown]
# TODO:
# 1. Automatically sort outputs from runnign SuperAnimal pipeline

# %% [markdown]
# ## 2. Convert and copy labels for anipose

# %%
# Batch convert all files in a folder
input_folder = "C:\\Users\\Gerardo\\Documents\\Lockbox\\rat_lockbox\\experiment\\240226_Rat_Lockbox_Cohort1_Combined_Lockbox_Task_Day1\\Box2\\pose-2d-raw\\"
output_folder = "C:\\Users\\Gerardo\\Documents\\Lockbox\\rat_lockbox\\experiment\\240226_Rat_Lockbox_Cohort1_Combined_Lockbox_Task_Day1\\Box2\\pose-2d\\"

# Batch convert all CSV and H5 files
batch_convert_superanimal_to_anipose(
    input_folder=input_folder,
    output_folder=output_folder,
    input_pattern="*.csv",  # Convert all CSVs
    also_convert_h5=True     # Also convert H5 files
)
# Out:
# Converted H5: C:\Users\Gerardo\Documents\Lockbox\rat_lockbox\experiment\240226_Rat_Lockbox_Cohort1_Combined_Lockbox_Task_Day1\Box2\pose-2d-raw\2026-02-24_11-49-50_23499131_rec.h5 -> C:\Users\Gerardo\Documents\Lockbox\rat_lockbox\experiment\240226_Rat_Lockbox_Cohort1_Combined_Lockbox_Task_Day1\Box2\pose-2d\2026-02-24_11-49-50_23499131_rec.h5
#
# ...
# Conversion complete!
# Converted 0 CSV files
# Converted 1 H5 files
# Output saved to: C:\Users\Gerardo\Documents\Lockbox\rat_lockbox\experiment\240226_Rat_Lockbox_Cohort1_Combined_Lockbox_Task_Day1\Box2\pose-2d\
# ...
